# %% [markdown]
# ## IQM Resonance Example Notebook
# In order to get started, make sure you have the appropriate packages installed. As prerequisite, you need to have **Python 3.11** or above and pip installed on your system.
#
# You have chosen IQM Emerald as your quantum computer. The following code snippet also shows how to create an IQM client and connect to this specific device.
#
# Run the cell and enter your IQM Resonance API token when prompted. You can find your API token in your IQM Resonance UI account drawer.
# In order to install the packages and init the backend to work with IQM hardware in QRISP, run the following cell:

# %%
import sys
import subprocess

# --- Check Python version ---
major, minor = sys.version_info[:2]

if not (major == 3 and minor == 12):
    print(f"❌ Python {major}.{minor} detected.")
    print("Please change the Colab runtime to **Python 3.11**:")
    print("Runtime → Change Runtime Type → Runtime Version → 2025.07")
    raise SystemExit

print(f"✅ Python {major}.{minor} detected (OK).")

# --- Check pip version ---
pip_version_output = subprocess.check_output(["pip", "--version"]).decode()
pip_version = pip_version_output.split()[1]  # e.g. "25.0"

print(f"Detected pip version: {pip_version}")

if not pip_version.startswith("25"):
    print("❌ pip version is not 25.x. Installing pip 25...")
    # !pip install --upgrade pip==25.*
    print("✅ pip 25 installed.")
    print("Please RESTART the runtime now (Runtime → Restart session).")
else:
    print("✅ pip 25.x is already installed.")
# Out:
# ✅ Python 3.12 detected (OK).
# Detected pip version: 25.3
# ✅ pip 25.x is already installed.

# %%
# install iqm-client with qrisp extras
# !pip install -U "iqm-client>=33.0.1" "qrisp[iqm]"
# used for visualization
# !pip install matplotlib

from qrisp.interface import IQMBackend
quantum_computer = IQMBackend(
    api_token = input("IQM Resonance API token"),
    device_instance = "sirius")
# Out:
# Requirement already satisfied: iqm-client>=33.0.1 in /usr/local/lib/python3.12/dist-packages (33.0.2)
# Requirement already satisfied: qrisp[iqm] in /usr/local/lib/python3.12/dist-packages (0.7.17)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (2.0.2)
# Requirement already satisfied: packaging==24.1 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (2.12.3)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (2.32.3)
# Requirement already satisfied: iqm-pulse<13,>=12.7.2 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (12.7.2)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.2 in /usr/local/lib/python3.12/dist-packages (from iqm-client>=33.0.1) (12.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client>=33.0.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client>=33.0.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client>=33.0.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.3->iqm-client>=33.0.1) (2025.11.12)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (2.19)
# Requirement already satisfied: python-rapidjson==1.20 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (1.20)
# Requirement already satisfied: jinja2==3.0.3 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (3.0.3)
# Requirement already satisfied: scipy<1.16,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (1.15.3)
# Requirement already satisfied: scipy-stubs in /usr/local/lib/python3.12/dist-packages (from iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (1.16.3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2==3.0.3->iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (3.0.3)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in /usr/local/lib/python3.12/dist-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (4.25.8)
# Requirement already satisfied: types-protobuf in /usr/local/lib/python3.12/dist-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (6.32.1.20251210)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.76.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (6.0.3)
# Requirement already satisfied: types-requests in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2.32.4.20250913)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (4.67.1)
# Requirement already satisfied: types-tqdm in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (4.67.0.20250809)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.2 in /usr/local/lib/python3.12/dist-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (27.4.2)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0,>=1.65.4->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (4.15.0)
# Requirement already satisfied: python-dotenv==0.21.1 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2024.10.0)
# Requirement already satisfied: ruamel-yaml==0.17.32 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (0.2.8)
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.16.0)
# Requirement already satisfied: types-six in /usr/local/lib/python3.12/dist-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.17.0.20251009)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2.2.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.72.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (1.27.0)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (0.48b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client>=33.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client>=33.0.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.9.2->iqm-client>=33.0.1) (0.4.2)
# Requirement already satisfied: sympy<=1.13 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (1.13.0)
# Requirement already satisfied: qiskit>=0.44.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (2.1.2)
# Requirement already satisfied: matplotlib>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.10.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.60.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.6.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.3.8)
# Requirement already satisfied: flask<2.3.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (2.2.5)
# Requirement already satisfied: waitress in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (3.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (5.9.5)
# Requirement already satisfied: jax==0.6.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.6.0)
# Requirement already satisfied: jaxlib==0.6.0 in /usr/local/lib/python3.12/dist-packages (from qrisp[iqm]) (0.6.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax==0.6.0->qrisp[iqm]) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax==0.6.0->qrisp[iqm]) (3.4.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from flask<2.3.0->qrisp[iqm]) (8.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy<=1.13->qrisp[iqm]) (1.3.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.1->qrisp[iqm]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client>=33.0.1) (2025.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp[iqm]) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.44.0->qrisp[iqm]) (5.6.0)
# Requirement already satisfied: qiskit-aer<0.18,>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->qrisp[iqm]) (0.43.0)
# Requirement already satisfied: optype<0.16,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (0.15.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in /usr/local/lib/python3.12/dist-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.2->iqm-client>=33.0.1) (20251206.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# IQM Resonance API token5r9aiHGLmYhL8Duu3VR/UDiyXuCqJU8LDJMjreXUDQQBmxh1Z/l+0qPaZRueIor/

# %% [markdown]
# After successfully installing the required packages and initializing the backend, you can submit the quantum circuit.

# %% [markdown]
# You have now successfully created a GHZ state on three qubits!.
#
# A GHZ state is named after Daniel Greenberger, Michael Horne, and Anton Zeilinger, who first described this type of entangled quantum state. It is a specific type of multi-qubit entangled state with two possible measurement outcomes: all qubits being in the state 0 or all qubits being in the state 1. The GHZ state is represented mathematically as:
# $$|GHZ_3⟩ = \frac{|000⟩ + |111⟩}{\sqrt{2}}$$
#
# This state is significant in quantum information theory and quantum computing because it exhibits strong correlations between the qubits, which cannot be explained by classical physics (in particular, it contradicts local hidden variable theories).
#
# You have successfully ran a quantum circuit. Please view the results in the IQM Resonance dashboard for further insights.
#
# Go to the [IQM Resonance](https://resonance.meetiqm.com).

# %%
import matplotlib.pyplot as plt
from dataclasses import dataclass
from typing import List, Tuple, Optional
import random

import qrisp as qlib # Import your own quantum library
from qrisp import QuantumVariable
from qrisp import h


def get_weights(d, r):
    if (d > r):
        return ((d-r), (r-d), 0)
    elif (d < r):
        return (0, 6, 0)
    else:
        return (-4, 4, 0)

def quantum_best_moves(soldiers):
    nsoldiers = sum(1 for x in soldiers if x.team == 'Quantum')
    qv = QuantumVariable(nsoldiers * 2)
    h(qv)
    result = qv.get_measurement(backend=quantum_computer)
    print(result)
    r = max(result, key=result.get)
    ret = [[0, 0] for x in range(nsoldiers)]
    for i in range(nsoldiers):
        if (r[i * 2] == '0'):
            ret[i][0] = -1
        else:
            ret[i][0] = 1
        if (r[i * 2 + 1] == '0'):
            ret[i][1] = -1
        else:
            ret[i][1] = 1
    return ret

"""
def quantum_best_move(soldier, enemy):
    qv = QuantumVariable(2)
    d = soldier.distance_to(enemy)
    r = soldier.range_dist
    w0, w1, w2 = get_weights(d, r)
    gamma = 0.85
    beta = 0.9

    cost_operator(qv, gamma, w0, w1, w2)
    mixer_operator(qv, beta)

    result = qv.get_measurement(backend=quantum_computer)
    stop = result['10'] + result['11']
    adv = result['01']

    nx = max(-1, min(1, enemy.x - soldier.x))
    ny = max(-1, min(1, enemy.y - soldier.y))

    if (stop > 0.5):
        print(soldier.unit_type, result, 'stop: ',stop, 'd: ', d, 'r: ', r)
        return (0,0)

    if (adv < 0.25):
        (nx, ny) = (-nx, -ny)
    else:
        if (soldier.x + nx == enemy.x and soldier.x + ny == enemy.y and nx != 0 and ny != 0):
            nx = 0
        print(soldier.unit_type, result, 'adv: ',adv, 'd: ', d, 'r: ', r)
    return (nx, ny)
"""

@dataclass
class Soldier:
    """Represents a single soldier on the battlefield."""
    x: float
    y: float
    strength: int  # 1, 2, 3 (low, medium, high)
    health: int    # 1, 2, 3 (low, medium, high)
    unit_type: str  # 'soldier', 'knight', 'archer'
    team: str  # 'Quantum' or 'Classical'
    range_dist: int  # 1, 2, 3 (low, medium, high)
    max_health: int = None  # Track original health for display

    def __post_init__(self):
        """Store max health after initialization."""
        if self.max_health is None:
            self.max_health = self.health

    def distance_to(self, other: 'Soldier') -> float:
        """Manhattan distance to another soldier."""
        return abs(self.x - other.x) + abs(self.y - other.y)

    def can_fight(self, other: 'Soldier') -> bool:
        """Check if this soldier can fight another."""
        return self.team != other.team and self.distance_to(other) <= self.range_dist

    def is_alive(self) -> bool:
        """Check if soldier is still alive."""
        return self.health >= 1

    def take_damage(self, damage: int):
        """Reduce health by damage amount. Health stays between 0 and 3."""
        self.health = max(0, min(3, self.health - damage))

    def attack(self, other: 'Soldier') -> int:
        """
        Attack another soldier and return damage dealt.
        Damage is based on strength (1, 2, or 3).
        Soldiers die when health drops below 1.
        """
        if not self.can_fight(other):
            return 0
        # Damage equals attacker's strength
        damage = self.strength
        other.take_damage(damage)
        return damage

class QuantumBattlefield:
    """Manages the battle simulation."""
    def __init__(self, width: int = 4, height: int = 4):
        self.width = width
        self.height = height
        self.board_size = width * height
        self.soldiers: List[Soldier] = []
        self.turn = 0
        self.history = {'team_a_count': [], 'team_b_count': [], 'turn': []}

    def add_soldier(self, soldier: Soldier):
        """Add a soldier to the battlefield."""
        self.soldiers.append(soldier)

    def initialize_team(self, team: str, composition: dict, start_x_range: Tuple[int, int]):
        """
        Initialize a team with given composition.

        Args:
            team: 'Quantum' or 'Classical'
            composition: {'unit_type': (count, strength, health, range_dist)}
            start_x_range: (x_min, x_max) for starting positions (inclusive)
        """
        # All possible x positions in the allowed range
        xs = range(start_x_range[0], start_x_range[1] + 1)
        ys = range(self.height)

        # Create a list of all (x, y) pairs
        all_positions = [(x, y) for x in xs for y in ys]
        random.shuffle(all_positions)
        pos_index = 0

        for unit_type, (count, strength, health, range_dist) in composition.items():
            for _ in range(count):
                if pos_index >= len(all_positions):
                    print(f"Warning: Not enough positions for all units!")
                    break

                x, y = all_positions[pos_index]
                pos_index += 1

                soldier = Soldier(x, y, strength, health, unit_type, team, range_dist)
                self.add_soldier(soldier)

    def record_history(self):
        """Record current soldier counts for this turn."""
        count_a = sum(1 for s in self.soldiers if s.team == 'Quantum')
        count_b = sum(1 for s in self.soldiers if s.team == 'Classical')
        self.history['team_a_count'].append(count_a)
        self.history['team_b_count'].append(count_b)
        self.history['turn'].append(self.turn)

    def move_soldiers(self, team:str):
        qmoves = quantum_best_moves(self.soldiers)
        q = 0
        for soldier in self.soldiers:
            if not soldier.is_alive() or soldier.team != team:
                continue
            if soldier.team == "Quantum":
                # take the best posible move
                # the function must return a tuple best_move = (x,y) based on the current position of the soldier
                # it can accept any desired extra argument
                best_move = qmoves[q]
                q += 1
            else:
                # the classical team moves using random walks
                best_move = (random.randint(-1, 1), random.randint(-1, 1))

            # clip to the grid
            new_x = max(0, min(self.width - 1, soldier.x +best_move[0]))
            new_y = max(0, min(self.height - 1, soldier.y + best_move[1]))
            # update position
            # if not self._is_position_occupied_by_teammate(new_x, new_y, soldier):
            if not self.is_position_occupied(new_x, new_y):
                # Update position only if not occupied by teammate
                soldier.x, soldier.y = new_x, new_y

    def _find_nearest_enemy(self, soldier: Soldier) -> Optional[Soldier]:
        """Find the nearest enemy soldier."""
        enemies = [s for s in self.soldiers if s.team != soldier.team and s.is_alive()]
        if not enemies:
            return None
        return min(enemies, key=lambda e: soldier.distance_to(e))

    def find_nearest_enemy_at(self, x: int, y: int) -> Optional[Soldier]:
        """Find the nearest enemy soldier."""
        enemies = [s for s in self.soldiers if s.team == 'Classical' and s.is_alive()]
        if not enemies:
            return None
        return min(enemies, key=lambda e: abs(x - e.x) + abs(y - e.y))

    def is_position_occupied(self, x:float, y:float) -> bool:
        for s in self.soldiers:
            if s.x == x and s.y == y:
              return True
        return False

    def _is_position_occupied_by_teammate(self, x: float, y: float, soldier: Soldier) -> bool:
        """Check if a position is occupied by a teammate."""
        for other in self.soldiers:
            if other is not soldier and other.is_alive() and other.team == soldier.team:
                if other.x == x and other.y == y:
                    return True
        return False

    def resolve_combat(self, team:str):
        """
        Resolve all combats this turn.
        Each soldier attacks enemies in range based on their strength.
        Soldiers die when health reaches 0.
        """
        combat_pairs = []

        # Find all valid combat pairs
        for i, attacker in enumerate(self.soldiers):
            if not attacker.is_alive() or attacker.team != team:
                continue

            # Find enemies in range
            targets = [s for s in self.soldiers if attacker.can_fight(s) and s.is_alive()]

            if targets:
                # Attack the weakest enemy in range (lowest current health)
                target = min(targets, key=lambda s: s.health)
                combat_pairs.append((attacker, target))

        # Execute all attacks
        for attacker, defender in combat_pairs:
            if attacker.is_alive() and defender.is_alive():
                attacker.attack(defender)

        # Remove dead soldiers
        self.soldiers = [s for s in self.soldiers if s.is_alive()]

    def step(self, team:str):
        """Execute one turn of the battle."""
        self.move_soldiers(team)
        self.resolve_combat(team)
        self.turn += 1
        self.record_history()

    def is_battle_over(self) -> bool:
        """Check if battle has ended."""
        count_a = sum(1 for s in self.soldiers if s.team == 'Quantum')
        count_b = sum(1 for s in self.soldiers if s.team == 'Classical')
        return count_a == 0 or count_b == 0

    def get_winner(self) -> str:
        """Return 'Quantum', 'Classical', or None."""
        count_a = sum(1 for s in self.soldiers if s.team == 'Quantum')
        count_b = sum(1 for s in self.soldiers if s.team == 'Classical')
        if count_a == 0 and count_b == 0:
            return None
        if count_a == 0:
            return 'Classical'
        if count_b == 0:
            return 'Quantum'
        return None

    def get_survivor_count(self) -> Tuple[int, int]:
        """Return (team_a_survivors, team_b_survivors)."""
        count_a = sum(1 for s in self.soldiers if s.team == 'Quantum')
        count_b = sum(1 for s in self.soldiers if s.team == 'Classical')
        return count_a, count_b

    def get_team_num_soldiers(self, team:str) -> int:
        r = 0
        for s in self.soldiers:
            if s.team == team:
                r += 1
        return r

def visualize_battle(battlefield: QuantumBattlefield, save_path: str = None):
    """Create a static visualization of the battlefield with unit types as markers."""
    fig, ax = plt.subplots()

    # Define markers for unit types
    markers = {'soldier': 'o', 'knight': 's', 'archer': '^'}
    colors = {'Quantum': 'royalblue', 'Classical': 'firebrick'}

    # Plot each combination of team and unit type
    for team in ['Quantum', 'Classical']:
        for unit_type, marker in markers.items():
            soldiers = [s for s in battlefield.soldiers
                       if s.team == team and s.unit_type == unit_type]
            if soldiers:
                ax.scatter([s.x for s in soldiers], [s.y for s in soldiers],
                          c=colors[team], marker=marker, s=100, alpha=0.7,
                          label=f'Team {team} - {unit_type}', edgecolors='black', linewidth=0.5)

    ax.set_xlim(-0.1, battlefield.width - 1  + 0.1)
    ax.set_xticks([x for x in range(battlefield.width)])
    ax.set_xticklabels([])
    ax.set_ylim(-0.1, battlefield.height - 1 + 0.1)
    ax.set_yticks([x for x in range(battlefield.height)])
    ax.set_yticklabels([])
    ax.set_aspect('equal')
    plt.tick_params(axis='both', direction='in')
    ax.grid(True, alpha=0.3)

    if save_path:
        plt.savefig(save_path)
    plt.show()

def plot_history(battlefield: QuantumBattlefield, save_path: str = None):
    """Plot team sizes over time."""
    plt.figure()
    plt.plot(battlefield.history['turn'], battlefield.history['team_a_count'],
             label='Team Quantum', color='royalblue', linewidth=2)
    plt.plot(battlefield.history['turn'], battlefield.history['team_b_count'],
             label='Team Firebrick', color='firebrick', linewidth=2)
    plt.xlabel('Turn')
    plt.xticks(battlefield.history['turn'])
    plt.ylabel('Soldier Count')
    plt.title('Team Size Over Time')
    plt.legend()
    plt.grid(True, alpha=0.3)

    if save_path:
        plt.savefig(save_path)
    plt.show()


comp = {
    'soldier': (1, 2, 3, 1),
    'knight':  (1, 3, 3, 1),
    'archer':  (1, 1, 2, 3),
}

width, height = 6, 4
battlefield = QuantumBattlefield(width=width, height=height)

battlefield.initialize_team(
    team='Quantum',
    composition=comp,
    start_x_range=(0, 0)
)

battlefield.initialize_team(
    team='Classical',
    composition=comp,
    start_x_range=(width - 1, width - 1)
)

visualize_battle(battlefield)
max_turns = 10
for _ in range(max_turns):
    if battlefield.is_battle_over():
        break
    battlefield.step('Quantum')
    print('Quantum')
    visualize_battle(battlefield)
    battlefield.step('Classical')
    print('Classical')
    visualize_battle(battlefield)

visualize_battle(battlefield)
plot_history(battlefield)

winner = battlefield.get_winner()
q_survivors, c_survivors = battlefield.get_survivor_count()
# Out:
# Progress in queue:   0%|          | 0/1 [00:00<?, ?it/s]
# {